# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv('C:/Users/91808/RP2 Internship/ml2/Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data.shape
# Out:
# (150, 6)

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris = {'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2}
data['Species'] = data['Species'].map(iris)

# %%
data['Species']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %% [markdown]
# ### Univariate analysis

# %%
plt.hist(data['SepalLengthCm'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(data['SepalWidthCm'],kde = True)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.countplot(data['Species'])
# Out:
# C:\Users\91808\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %%
sns.lineplot(x = data['PetalWidthCm'],y = data['Species'],label = 'PetalWidthCm')
sns.lineplot(x = data['PetalLengthCm'],y = data['Species'],label = 'PetalLengthCm')
sns.lineplot(x = data['SepalWidthCm'],y = data['Species'],label = 'SepalWidthCm')
sns.lineplot(x = data['SepalLengthCm'],y = data['Species'],label = 'SepalLengthCm')
plt.legend()

# %% [markdown]
# ### Data modeling and evaluation

# %%
x = data.drop(columns = ['Id','Species'],axis = 1)
y = data['Species']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %% [markdown]
# #### Logistic regresswion

# %%
model1 = LogisticRegression()
model1.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model1.score(xtest,ytest)
# Out:
# 1.0

# %% [markdown]
# #### SVM

# %%
model2 = SVC()
model2.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
model2.score(xtest,ytest)
# Out:
# 1.0

# %% [markdown]
# ### Decision tree

# %%
model3 = DecisionTreeClassifier()
model3.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
model4 = DecisionTreeClassifier()
model4.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
model4.score(xtest,ytest)
# Out:
# 1.0

# %% [markdown]
# #### Random forest

# %%
model5 = RandomForestClassifier()
model5.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
model5.score(xtest,ytest)
# Out:
# 1.0

# %% [markdown]
# #### KNN

# %%
model6 = KNeighborsClassifier()
model6.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
model6.score(xtest,ytest)
# Out:
# 1.0
